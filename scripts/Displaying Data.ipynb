# %%
import pandas as pd
import pickle
import numpy

# %%
terminal_dict = pickle.load( open("data.p", "rb" ) )

# %%
terminal_dict
# Out:
# {'ego_3_1024,seed_0,teb_big_radius': {'calculateEquivalenceClass': 0.2827379512017467,
#   'graphGen': 0.053569249999999694,
#   'insertPoints': 0.0,
#   'num_gaps': 10.843406593406593,
#   'obsCount': 32.37637362637363,
#   'optimizeGraph': 58.135240696561965,
#   'update': 0.0},
#  'ego_3_1024,seed_0,teb_reg_radius': {'calculateEquivalenceClass': 0.30191371928571387,
#   'graphGen': 0.04520330684931498,
#   'insertPoints': 0.0,
#   'num_gaps': 10.92054794520548,
#   'obsCount': 32.33150684931507,
#   'optimizeGraph': 57.78245785207742,
#   'update': 0.003988035892323033},
#  'ego_3_1024,seed_0,teb_small_radius': {'calculateEquivalenceClass': 0.3008315059435347,
#   'graphGen': 0.03730746703296676,
#   'insertPoints': 0.0,
#   'num_gaps': 10.87087912087912,
#   'obsCount': 32.47802197802198,
#   'optimizeGraph': 58.39501506403377,
#   'update': 0.000997008973080758},
#  'ego_3_256,seed_0,teb_big_radius': {'calculateEquivalenceClass': 0.2732301882783886,
# ...

# %%
df = pd.DataFrame(data=terminal_dict)

# %%
df.transpose()
# Out:
#                                     calculateEquivalenceClass  graphGen  \
# ego_3_1024,seed_0,teb_big_radius                     0.282738  0.053569
# ego_3_1024,seed_0,teb_reg_radius                     0.301914  0.045203
# ego_3_1024,seed_0,teb_small_radius                   0.300832  0.037307
# ego_3_256,seed_0,teb_big_radius                      0.273230  0.031266
# ego_3_256,seed_0,teb_reg_radius                      0.271738  0.040793
# ego_3_256,seed_0,teb_small_radius                    0.276477  0.020570
# ego_3_512,seed_0,teb_big_radius                      0.278332  0.031766
# ego_3_512,seed_0,teb_reg_radius                      0.275297  0.029636
# ego_3_512,seed_0,teb_small_radius                    0.264796  0.028546
# ego_4_1024,seed_0,teb_big_radius                     0.758987  0.398471
# ego_4_1024,seed_0,teb_reg_radius                     0.768367  0.378103
# ego_4_1024,seed_0,teb_small_radius                   0.773705  0.464964
# ...
